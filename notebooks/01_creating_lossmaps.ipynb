# %%
# This is to access the package without it being installed for testing.
from pathlib import Path
import sys
sys.path.append(str(Path.cwd().parent))

# %%
from pylossmap.fetcher import BLMDataFetcher
# Out:
# /home/lcoyle/anaconda2/envs/loss_maps/lib/python3.7/site-packages/jpype/_core.py:210: UserWarning:
# -------------------------------------------------------------------------------
# Deprecated: convertStrings was not specified when starting the JVM. The default
# behavior in JPype will be False starting in JPype 0.8. The recommended setting
# for new code is convertStrings=False.  The legacy value of True was assumed for
# this session. If you are a user of an application that reported this warning,
# please file a ticket with the developer.
# -------------------------------------------------------------------------------
#
#   """)

# %% [markdown]
# # Fetching BLM data
#
# See the `00_fetching_data` notebook

# %%
fetcher = BLMDataFetcher()

# %%
BLM_data = fetcher.from_fill(7247, beam_modes=['INJPHYS'], unique_beam_modes=True)
# if a fill has multiple of the same beam mode, they will be made unique, use unique_beam_modes=True,
# to control which of them to fetch. To get the second occurance of INJPHYS, use INJPHYS_2, with
# unique_beam_mode=True.
# Out:
# Beam mode INJPHYS
# 10-02 10:14:15 ▶10-02 10:42:22

# %%
BLM_data.df
# Out:
#                                              BLMQI.01R1.B2I30_MQXA  \
# mode    timestamp
# INJPHYS 2018-10-02 10:14:15.771000147+02:00           4.750000e-07
#         2018-10-02 10:14:16.835999966+02:00           4.419000e-07
#         2018-10-02 10:14:17.831000090+02:00           4.502000e-07
#         2018-10-02 10:14:18.753999949+02:00           4.861000e-07
#         2018-10-02 10:14:19.762000084+02:00           4.032000e-07
# ...                                                            ...
#         2018-10-02 10:42:17.756000042+02:00           4.640000e-07
#         2018-10-02 10:42:18.844000101+02:00           4.032000e-07
#         2018-10-02 10:42:19.773999929+02:00           4.419000e-07
#         2018-10-02 10:42:20.759999990+02:00           4.336000e-07
#         2018-10-02 10:42:21.782999992+02:00           4.308000e-07
#
#                                              BLMQI.01R1.B1E10_MQXA  \
# mode    timestamp
# INJPHYS 2018-10-02 10:14:15.771000147+02:00           4.364000e-07
#         2018-10-02 10:14:16.835999966+02:00           5.137000e-07
#         2018-10-02 10:14:17.831000090+02:00           4.612000e-07
#         2018-10-02 10:14:18.753999949+02:00           5.027000e-07
#         2018-10-02 10:14:19.762000084+02:00           4.971000e-07
# ...                                                            ...
#         2018-10-02 10:42:17.756000042+02:00           4.612000e-07
#         2018-10-02 10:42:18.844000101+02:00           4.806000e-07
#         2018-10-02 10:42:19.773999929+02:00           4.723000e-07
#         2018-10-02 10:42:20.759999990+02:00           4.668000e-07
#         2018-10-02 10:42:21.782999992+02:00           4.833000e-07
#
#                                              BLMQI.01R1.B2I20_MQXA  \
# mode    timestamp
# INJPHYS 2018-10-02 10:14:15.771000147+02:00           3.811000e-07
#         2018-10-02 10:14:16.835999966+02:00           5.330000e-07
#         2018-10-02 10:14:17.831000090+02:00           4.557000e-07
#         2018-10-02 10:14:18.753999949+02:00           4.971000e-07
#         2018-10-02 10:14:19.762000084+02:00           5.137000e-07
# ...                                                            ...
#         2018-10-02 10:42:17.756000042+02:00           3.369000e-07
#         2018-10-02 10:42:18.844000101+02:00           4.391000e-07
#         2018-10-02 10:42:19.773999929+02:00           4.723000e-07
#         2018-10-02 10:42:20.759999990+02:00           4.806000e-07
#         2018-10-02 10:42:21.782999992+02:00           4.474000e-07
#
#                                              BLMQI.01R1.B1E20_MQXA  \
# mode    timestamp
# INJPHYS 2018-10-02 10:14:15.771000147+02:00           6.573000e-07
#         2018-10-02 10:14:16.835999966+02:00           6.932000e-07
#         2018-10-02 10:14:17.831000090+02:00           6.269000e-07
#         2018-10-02 10:14:18.753999949+02:00           6.463000e-07
#         2018-10-02 10:14:19.762000084+02:00           6.987000e-07
# ...                                                            ...
#         2018-10-02 10:42:17.756000042+02:00           6.048000e-07
#         2018-10-02 10:42:18.844000101+02:00           6.187000e-07
#         2018-10-02 10:42:19.773999929+02:00           6.380000e-07
#         2018-10-02 10:42:20.759999990+02:00           6.352000e-07
#         2018-10-02 10:42:21.782999992+02:00           6.187000e-07
#
#                                              BLMQI.02R1.B2I30_MQXB  \
# mode    timestamp
# INJPHYS 2018-10-02 10:14:15.771000147+02:00
e-07
# ...                                                            ...
#         2018-10-02 10:42:17.756000042+02:00           3.508000e-07
#         2018-10-02 10:42:18.844000101+02:00           3.839000e-07
#         2018-10-02 10:42:19.773999929+02:00           4.115000e-07
#         2018-10-02 10:42:20.759999990+02:00           3.949000e-07
#         2018-10-02 10:42:21.782999992+02:00           3.839000e-07
#
#                                              BLMQI.01L1.B1I30_MQXA
# mode    timestamp
# INJPHYS 2018-10-02 10:14:15.771000147+02:00           5.386000e-07
#         2018-10-02 10:14:16.835999966+02:00           5.082000e-07
#         2018-10-02 10:14:17.831000090+02:00           4.750000e-07
#         2018-10-02 10:14:18.753999949+02:00           5.386000e-07
#         2018-10-02 10:14:19.762000084+02:00           4.281000e-07
# ...                                                            ...
#         2018-10-02 10:42:17.756000042+02:00           4.916000e-07
#         2018-10-02 10:42:18.844000101+02:00           5.109000e-07
#         2018-10-02 10:42:19.773999929+02:00           5.220000e-07
#         2018-10-02 10:42:20.759999990+02:00           4.861000e-07
#         2018-10-02 10:42:21.782999992+02:00           4.833000e-07
#
# [1687 rows x 3595 columns]

# %%
BLM_data.plot()
# Out:
# {'INJPHYS': (<Figure size 1440x720 with 1 Axes>,
#   <matplotlib.axes._subplots.AxesSubplot at 0x7f3baf86e990>)}

# %% [markdown]
# This data comes from operational data, we can get a background signal by looking at the INJPROT beam mode when there is no beam.
#
# This is done in the `bg_from_INJPROT` method.

# %%
BLM_bg = fetcher.bg_from_INJPROT(7247)
BLM_bg.fetch_intensity(beam=1).plot(title='Background beam intensity')
# no intensity --> no beam
BLM_bg.plot()
LM_bg = BLM_bg.loss_map(row=BLM_bg.df.mean())
LM_bg.plot()
# Out:
# Beam mode INJPROT
# 10-02 09:48:49 ▶10-02 09:55:32
# (<Figure size 1440x720 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f3bae1aab50>)

# %% [markdown]
# "Loss maps" for the timestamps where the primary BLMs are maximum.

# %%
for idx, blms in BLM_data.iter_max():
    print(idx)
    LM = BLM_data.loss_map(datetime=idx[1],
                           context=blms)
    # the context kwargs allow you to pass some additional information of the loss map's origin
    LM.set_background(LM_bg)
    LM.clean_background().normalize().plot(title=f"{idx[1]} {idx[0]}\n{'  '.join(blms)}")
# Out:
# ('INJPHYS', Timestamp('2018-10-02 10:14:24.736000061+0200', tz='Europe/Zurich'))
# ('INJPHYS', Timestamp('2018-10-02 10:21:31.855000019+0200', tz='Europe/Zurich'))
# ('INJPHYS', Timestamp('2018-10-02 10:40:34.857000113+0200', tz='Europe/Zurich'))
# /home/lcoyle/anaconda2/envs/loss_maps/lib/python3.7/site-packages/pandas/core/indexes/base.py:3071: FutureWarning: Converting timezone-aware DatetimeArray to timezone-naive ndarray with 'datetime64[ns]' dtype. In the future, this will return an ndarray with 'object' dtype where each element is a 'pandas.Timestamp' with the correct 'tz'.
# 	To accept the future behavior, pass 'dtype=object'.
# 	To keep the old behavior, pass 'dtype="datetime64[ns]"'.
#   target = np.asarray(target)
# ('INJPHYS', Timestamp('2018-10-02 10:40:03.769000053+0200', tz='Europe/Zurich'))

# %%
LM
# Out:
# LossMap:
# 	data:
#                                data     dcum  type
# BLMQI.01R1.B2I30_MQXA  4.668000e-07     2137  cold
# BLMQI.01R1.B1E10_MQXA  4.723000e-07     2344  cold
# BLMQI.01R1.B2I20_MQXA  4.778000e-07     2563  cold
# BLMQI.01R1.B1E20_MQXA  6.407000e-07     2665  cold
# BLMQI.02R1.B2I30_MQXB  6.711000e-07     2975  cold
# ...                             ...      ...   ...
# BLMQI.02L1.B1I30_MQXB  6.518000e-07  2662903  cold
# BLMQI.01L1.B2E20_MQXA  6.822000e-07  2663223  cold
# BLMQI.01L1.B1I20_MQXA  5.386000e-07  2663323  cold
# BLMQI.01L1.B2E10_MQXA  4.253000e-07  2663545  cold
# BLMQI.01L1.B1I30_MQXA  4.557000e-07  2663738  cold
#
# [3595 rows x 3 columns]
# 	background:
#                                data     dcum  type
# BLMQI.01R1.B2I30_MQXA  4.870940e-07     2137  cold
# BLMQI.01R1.B1E10_MQXA  5.034759e-07     2344  cold
# BLMQI.01R1.B2I20_MQXA  5.050993e-07     2563  cold
# BLMQI.01R1.B1E20_MQXA  6.973623e-07     2665  cold
# BLMQI.02R1.B2I30_MQXB  7.444464e-07     2975  cold
# ...                             ...      ...   ...
# BLMQI.02L1.B1I30_MQXB  7.033112e-07  2662903  cold
# BLMQI.01L1.B2E20_MQXA  6.910285e-07  2663223  cold
# BLMQI.01L1.B1I20_MQXA  5.000571e-07  2663323  cold
# BLMQI.01L1.B2E10_MQXA  4.167377e-07  2663545  cold
# BLMQI.01L1.B1I30_MQXA  5.275097e-07  2663738  cold
#
# [3595 rows x 3 columns]

# %% [markdown]
# # processing the LossMap

# %% [markdown]
# This loss map is for the maxima of:

# %%
LM.context
# Out:
# ['BLMTI.06R7.B2I10_TCP.B6R7.B2',
#  'BLMTI.06R7.B2I10_TCP.C6R7.B2',
#  'BLMTI.06R7.B2I10_TCP.D6R7.B2']

# %% [markdown]
# # cleaning and normalizing

# %%
LM_clean = LM.clean_background().normalize()
LM_clean.plot()
# Out:
# (<Figure size 1440x720 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f3b88445310>)

# %% [markdown]
# # Filtering BLMs

# %% [markdown]
# The LossMap class has some filtering methods, some examples of what can be done is shown below.

# %%
LM_clean.beam(1).IR(7).plot()
# Out:
# (<Figure size 1440x720 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f3b88258050>)

# %%
LM_clean.IR(7).beam(2).plot()
# Out:
# (<Figure size 1440x720 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f3b8843ea90>)

# %% [markdown]
# Dispersion suppressors around IR7

# %%
LM_clean.IR(7).DS().plot()
# Out:
# (<Figure size 1440x720 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f3bae1c5c50>)

# %% [markdown]
# TCPs right side of IR7

# %%
LM_clean.IR(7).side('R').TCP().plot()
# Out:
# (<Figure size 1440x720 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f3b88399e90>)

# %% [markdown]
# Cold collimators in Cells 4,5,6,7,8,9 of IR 5 and 7

# %%
LM_clean.cell(4,5,6,7,8,9).type('cold').IR(7,5).plot()
# Out:
# (<Figure size 1440x720 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f3bac0cbcd0>)

# %%
LM_clean.type('coll').plot()
# Out:
# (<Figure size 1440x720 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f3bac48c9d0>)

# %% [markdown]
# custom filter

# %%
LM_clean.filter(r'BLM(EL|QI)').IR(7).plot()
# Out:
# (<Figure size 1440x720 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f3bac3660d0>)

# %% [markdown]
# The LossMap's get & set items are forwarded to LossMap.data which allows for easier pandas style filtering

# %%
LM_2 = LM_clean[LM_clean.df['dcum'] < 100000]
LM_2.plot()
# Out:
# (<Figure size 1440x720 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f3b882143d0>)

# %%
LM_clean.plot()
# Out:
# (<Figure size 1440x720 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f3bac23fc50>)
